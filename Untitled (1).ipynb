# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('ifood_df.csv')
data.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# 0              172                88            88  ...                 0
# 1                2                 1             6  ...                 0
# 2              111                21            42  ...                 1
# 3               10                 3             5  ...                 1
# 4               46                27            15  ...                 0
#
# ...

# %%
data.shape
# Out:
# (2205, 39)

# %%
data.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean    51622.094785     0.442177     0.506576    49.009070   306.164626
# std     20713.063826     0.537132     0.544380    28.932111   337.493839
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35196.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51287.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68281.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2205.000000      2205.000000      2205.000000       2205.000000
# mean     26.403175       165.312018        37.756463         27.128345
# std      39.784484       217.784507        54.824635         41.130468
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Income                2205 non-null   float64
#  1   Kidhome               2205 non-null   int64
#  2   Teenhome              2205 non-null   int64
#  3   Recency               2205 non-null   int64
#  4   MntWines              2205 non-null   int64
#  5   MntFruits             2205 non-null   int64
#  6   MntMeatProducts       2205 non-null   int64
#  7   MntFishProducts       2205 non-null   int64
#  8   MntSweetProducts      2205 non-null   int64
#  9   MntGoldProds          2205 non-null   int64
#  10  NumDealsPurchases     2205 non-null   int64
#  11  NumWebPurchases       2205 non-null   int64
#  12  NumCatalogPurchases   2205 non-null   int64
#  13  NumStorePurchases     2205 non-null   int64
#  14  NumWebVisitsMonth     2205 non-null   int64
# ...

# %%
data.isnull().sum()
# Out:
# Income                  0
# Kidhome                 0
# Teenhome                0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# Age                     0
# Customer_Days           0
# marital_Divorced        0
# marital_Married         0
# marital_Single          0
# marital_Together        0
# marital_Widow           0
# education_2n Cycle      0
# education_Basic         0
# education_Graduation    0
# education_Master        0
# ...

# %%
# KDE plot for income distribution
plt.figure(figsize=(8, 6))
sns.kdeplot(data=data, x='Income', fill=True, color='skyblue')
plt.xlabel('Income')
plt.ylabel('Density')
plt.title('Income Distribution')
plt.show()

# %%
# KDE plot for income distribution
plt.figure(figsize=(8, 6))
sns.kdeplot(data=data, x='Recency', fill=True, color='skyblue')
plt.xlabel('Recency')
plt.ylabel('Density')
plt.title('Recency Distribution')
plt.show()

# %%
# Box plot of amount spent on wines and gold products
plt.figure(figsize=(8, 6))
sns.boxplot(data=data[['MntWines', 'MntFruits','MntSweetProducts','MntGoldProds']])
plt.xlabel('Product Category')
plt.ylabel('Amount Spent')
plt.title('Amount Spent on Wines, Gold Products, Fruits and sweets')
plt.show()

# %%
# Scatter plot of number of web visits and response
plt.figure(figsize=(8, 6))
sns.scatterplot(data=data, x='NumWebVisitsMonth', y='Response', hue='Response')
plt.xlabel('Number of Web Visits')
plt.ylabel('Response')
plt.title('Web Visits vs. Response')
plt.show()

# %%
# Box plot of amount spent on wines and gold products
plt.figure(figsize=(8, 6))
sns.barplot(data=data[['NumWebPurchases', 'NumCatalogPurchases','NumStorePurchases']])
plt.xlabel('Number of Purchase')
plt.ylabel('Number')
plt.title('Purchasing Number of Catlog, Store, Web')
plt.show()

# %%
# Select the categorical columns of interest
categorical_columns = ['AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2', 'Complain']

# Count analysis for each categorical column
for column in categorical_columns:
    plt.figure(figsize=(8, 6))
    sns.countplot(data=data, x=column)
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.title(f'Count Analysis - {column}')
    plt.show()

# %%
# KDE plot for income distribution
plt.figure(figsize=(8, 6))
sns.kdeplot(data=data, x='Age', fill=True, color='skyblue')
plt.xlabel('Recency')
plt.ylabel('Density')
plt.title('Recency Distribution')
plt.show()

# %%
# Select the categorical columns of interest
categorical_columns = ['marital_Divorced', 'marital_Married', 'marital_Single', 'marital_Together', 'marital_Widow']

# Count analysis for each categorical column
for column in categorical_columns:
    plt.figure(figsize=(8, 6))
    sns.countplot(data=data, x=column)
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.title(f'Count Analysis - {column}')
    plt.show()

# %%
# Analysis of MntTotal
plt.figure(figsize=(8, 6))
sns.histplot(data=data, x='MntTotal', bins=10, kde=True)
plt.xlabel('Total Amount Spent')
plt.ylabel('Count')
plt.title('Distribution of Total Amount Spent')
plt.show()

# %%
# Analysis of MntRegularProds
plt.figure(figsize=(8, 6))
sns.histplot(data=data, x='MntRegularProds', bins=10, kde=True)
plt.xlabel('Amount Spent on Regular Products')
plt.ylabel('Count')
plt.title('Distribution of Amount Spent on Regular Products')
plt.show()

# %%
# Analysis of AcceptedCmpOverall
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='AcceptedCmpOverall')
plt.xlabel('Campaign Overall Acceptance')
plt.ylabel('Count')
plt.title('Campaign Overall Acceptance Analysis')
plt.show()

# %% [markdown]
# <p>Based on the analysis of the dataset, here is a detailed interpretation for making business decisions:
#
# Campaign Acceptance (AcceptedCapl, AcceptedCmp2, AcceptedCmp3, AcceptedCmpd, AcceptedCmps): The count analysis of these columns provides insights into the acceptance rates of different campaigns. By comparing the acceptance levels across campaigns, the business can identify which campaigns are more successful in engaging customers and driving positive responses. This information can be used to allocate resources effectively and invest in campaigns that yield higher acceptance rates.
#
# Response (target): The distribution and analysis of the response column provide an understanding of the overall response rate to the marketing campaigns. By evaluating the response rate, the business can assess the effectiveness of the campaigns and make informed decisions about campaign strategies, targeting specific customer segments, or refining marketing messages to improve response rates.
#
# Complain: The count analysis of the complain column helps identify the number of customer complaints. High complaint rates might indicate areas of improvement in customer experience, product quality, or customer service. Addressing these concerns can lead to better customer satisfaction, retention, and ultimately, improved business performance.
#
# Education and Marital Status: Analyzing the education and marital status columns allows the business to understand the demographic profile of their customers. This information can be used for targeted marketing strategies, tailoring campaigns to specific customer segments based on their education and marital status. It can also help in identifying potential customer needs, preferences, and behavior patterns.
#
# Household Composition (Kidhome, Teenhome): The analysis of these columns provides insights into the number of children and teenagers in customer households. This information can be valuable for designing marketing campaigns and product offerings that cater to the needs and preferences of families with different household compositions. Understanding the customer's family dynamics can aid in creating relevant and appealing promotions or products.
#
# Income: The analysis of income distribution allows the business to understand the purchasing power of its customer base. It helps identify different customer segments based on their income levels and enables targeted marketing strategies. By tailoring pricing, discounts, or product offerings based on income segments, the business can optimize revenue and cater to the specific needs and preferences of different income groups.
#
# Product Preferences (MutFishProducts, MutMeatProducts, MntFruits, MutSweetProducts, MutWines, MutGoldProds): The analysis of these columns provides insights into customers' preferences for various product categories. By understanding the purchasing patterns and spending behavior of customers in different product categories, the business can tailor product offerings, promotions, and marketing strategies to align with customer preferences. This information can help optimize product assortment, pricing, and targeted marketing efforts.
#
# Purchasing Behavior (NumDealsPurchases, NumCatalogPurchases, NumStorePurchases, NumWebPurchases, NumWebVisitsMonth): The analysis of these columns allows the business to understand the customers' purchasing behavior across different channels. By analyzing the number of purchases through various channels and the frequency of web visits, the business can identify the preferred channels and optimize its marketing and sales strategies accordingly. It helps allocate resources effectively and improve the customer journey by focusing on the preferred channels for customer engagement and conversions.
#
# Recency: The recency column indicates the number of days since the last purchase made by customers. Analyzing this column helps identify customers who have not made recent purchases, potentially indicating churn or a decline in engagement. Businesses can use this information to target customers who are at risk of attrition and implement strategies to re-engage them through personalized offers, promotions, or customer retention initiatives.
#
# By considering these interpretations, businesses can make informed decisions about their marketing strategies, campaign targeting, product offerings, and customer retention initiatives. The analysis provides insights into customer preferences, behavior, and demographic profiles, enabling businesses to optimize their operations, drive revenue growth, and enhance customer satisfaction.
#
#
#
#
# </p>
